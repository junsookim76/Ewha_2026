# %% [markdown]
# <a href="https://colab.research.google.com/github/junsookim76/Ewha_2026/blob/main/4_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas 기초 강의 노트
# 이 노트북은 Pandas를 처음 사용하는 학생들을 위한 예제 중심의 강의 자료입니다.

# %% [markdown]
# ## 1. Pandas 소개
# - Pandas는 Python에서 데이터 처리를 쉽게 해주는 라이브러리입니다.
# - 표 형식의 데이터를 다루기에 매우 유용합니다.
#
# ```bash
# pip install pandas
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Series와 DataFrame
# - **Series**: 1차원 데이터
# - **DataFrame**: 2차원 표 형식 데이터

# %%
s = pd.Series([10, 20, 30, 40])
print(s)
print(type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data = {
    '이름': ['영희', '철수', '민수'],
    '국어': [90, 85, 80],
    '수학': [88, 90, 95]
}
df = pd.DataFrame(data)
df
# Out:
#    이름  국어  수학
# 0  영희  90  88
# 1  철수  85  90
# 2  민수  80  95

# %% [markdown]
# ## 3. CSV 파일 불러오기
# `pd.read_csv()`를 사용해서 CSV 파일을 불러올 수 있습니다.

# %%
# 예제용 CSV 파일 다운로드 (인터넷 연결 필요)
url = 'https://raw.githubusercontent.com/junsookim76/Ewha_2026/main/iris3.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## 4. DataFrame 기초 탐색
# - `head()`, `tail()`, `info()`, `describe()` 등을 사용

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## 5. 인덱싱과 슬라이싱
# - 열 선택: `df['열이름']`
# - 행 선택: `df.loc[]`, `df.iloc[]`

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.loc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 6. 조건으로 필터링
# - 특정 조건을 만족하는 행만 선택

# %%
df[df['species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ## 7. 간단한 시각화
# - `matplotlib`을 이용한 기본 시각화

# %%
df['sepal_length'].hist()
plt.title('Sepal Length Histogram')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Exercise 1. 주기율표 다루기

# %%
# !git clone https://gist.github.com/c2dd862cd38f21b0ad36b8f96b4bf1ee.git
# Out:
# Cloning into 'c2dd862cd38f21b0ad36b8f96b4bf1ee'...
# remote: Enumerating objects: 11, done.
# remote: Total 11 (delta 0), reused 0 (delta 0), pack-reused 11 (from 1)
# Receiving objects: 100% (11/11), 8.14 KiB | 8.14 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# /content/에 불러온 c2dd862cd38f21b0ad36b8f96b4bf1ee 폴더의 이름 바꾸기

# !mv /content/c2dd862cd38f21b0ad36b8f96b4bf1ee /content/Periodic_Table

# %%
df1 = pd.read_csv("/content/Periodic_Table/Periodic Table of Elements.csv")
df1.head()
# Out:
#    AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# 0             1   Hydrogen      H       1.007                 0
# 1             2     Helium     He       4.002                 2
# 2             3    Lithium     Li       6.941                 4
# 3             4  Beryllium     Be       9.012                 5
# 4             5      Boron      B      10.811                 6
#
#    NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 0                1                  1       1    1.0    gas  ...
# 1                2                  2       1   18.0    gas  ...
# 2                3                  3       2    1.0  solid  ...
# 3                4                  4       2    2.0  solid  ...
# 4                5                  5       2   13.0  solid  ...
#
#   FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0         13.5984  0.000090       14.175        20.28              3.0
# ...

# %%
df1.tail()
# Out:
#      AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# 113           114    Flerovium     Fl       289.0               175
# 114           115    Moscovium     Mc       288.0               173
# 115           116  Livermorium     Lv       292.0               176
# 116           117   Tennessine     Ts       295.0               178
# 117           118    Oganesson     Og       294.0               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 113              114                114       7   14.0  artificial  ...
# 114              115                115       7   15.0  artificial  ...
# 115              116                116       7   16.0  artificial  ...
# 116              117                117       7   17.0  artificial  ...
# 117              118                118       7   18.0  artificial  ...
#
#     FirstIonization Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# ...

# %%
df1.describe()
# Out:
#        AtomicNumber  AtomicMass  NumberofNeutrons  NumberofProtons  \
# count    118.000000  118.000000        118.000000       118.000000
# mean      59.500000  145.988297         86.483051        59.500000
# std       34.207699   88.954899         54.785320        34.207699
# min        1.000000    1.007000          0.000000         1.000000
# 25%       30.250000   66.465750         36.000000        30.250000
# 50%       59.500000  142.575000         83.000000        59.500000
# 75%       88.750000  226.750000        138.000000        88.750000
# max      118.000000  295.000000        178.000000       118.000000
#
#        NumberofElectrons      Period      Group  AtomicRadius  \
# count         118.000000  118.000000  90.000000     86.000000
# mean           59.500000    5.254237   9.944444      1.825814
# std            34.207699    1.618200   5.597674      0.611058
# min             1.000000    1.000000   1.000000      0.490000
# ...

# %%
df1['Element'].unique()
# Out:
# array(['Hydrogen', 'Helium', 'Lithium', 'Beryllium', 'Boron', 'Carbon',
#        'Nitrogen', 'Oxygen', 'Fluorine', 'Neon', 'Sodium', 'Magnesium',
#        'Aluminum', 'Silicon', 'Phosphorus', 'Sulfur', 'Chlorine', 'Argon',
#        'Potassium', 'Calcium', 'Scandium', 'Titanium', 'Vanadium',
#        'Chromium', 'Manganese', 'Iron', 'Cobalt', 'Nickel', 'Copper',
#        'Zinc', 'Gallium', 'Germanium', 'Arsenic', 'Selenium', 'Bromine',
#        'Krypton', 'Rubidium', 'Strontium', 'Yttrium', 'Zirconium',
#        'Niobium', 'Molybdenum', 'Technetium', 'Ruthenium', 'Rhodium',
#        'Palladium', 'Silver', 'Cadmium', 'Indium', 'Tin', 'Antimony',
#        'Tellurium', 'Iodine', 'Xenon', 'Cesium', 'Barium', 'Lanthanum',
#        'Cerium', 'Praseodymium', 'Neodymium', 'Promethium', 'Samarium',
#        'Europium', 'Gadolinium', 'Terbium', 'Dysprosium', 'Holmium',
#        'Erbium', 'Thulium', 'Ytterbium', 'Lutetium', 'Hafnium',
# ...

# %%
df1.iloc[3:5]
# Out:
#    AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# 3             4  Beryllium     Be       9.012                 5
# 4             5      Boron      B      10.811                 6
#
#    NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 3                4                  4       2    2.0  solid  ...
# 4                5                  5       2   13.0  solid  ...
#
#   FirstIonization Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 3          9.3227    1.85      1560.15       2742.0              6.0
# 4          8.2980    2.34      2573.15       4200.0              6.0
#
#    Discoverer    Year  SpecificHeat  NumberofShells  NumberofValence
# 3  Vaulquelin  1798.0         1.825               2              2.0
# 4  Gay-Lussac  1808.0         1.026               2              3.0
#
# [2 rows x 28 columns]

# %%
df1[df1['Period'] == 3]
# Out:
#     AtomicNumber     Element Symbol  AtomicMass  NumberofNeutrons  \
# 10            11      Sodium     Na      22.990                12
# 11            12   Magnesium     Mg      24.305                12
# 12            13    Aluminum     Al      26.982                14
# 13            14     Silicon     Si      28.086                14
# 14            15  Phosphorus      P      30.974                16
# 15            16      Sulfur      S      32.065                16
# 16            17    Chlorine     Cl      35.453                18
# 17            18       Argon     Ar      39.948                22
#
#     NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 10               11                 11       3    1.0  solid  ...
# 11               12                 12       3    2.0  solid  ...
# 12               13                 13       3   13.0  solid  ...
# 13               14                 14       3   14.0  solid  ...
# ...

# %%
df1['MeltingPoint'].hist()
plt.title('Melting Point Histogram')
plt.xlabel('Melting Point')
plt.ylabel('Frequency')
plt.show()
