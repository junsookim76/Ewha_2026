# %% [markdown]
# <a href="https://colab.research.google.com/github/junsookim76/Ewha_2026/blob/main/2_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy
#
# > Import "numpy"
# >
# > The fundamental package for scientific computing with Python

# %%
import numpy as np

import matplotlib.pyplot as plt
import sys,os,copy,random,math
# %matplotlib inline

# %% [markdown]
# ## **1. Introducing numpy array**

# %%
array=[1,2,3,4,5,6,7,8]

print(array)
print(type(array))
print(len(array))

numpy_array=np.array(array)
print(type(numpy_array))
print(numpy_array)
print(numpy_array.dtype)
print(numpy_array.shape)

# %%
array2=2*array

print(array)
print(array2)

numpy_array2=2*numpy_array
print(numpy_array)
print(numpy_array2)

# %%
numpy_array3=np.array([1,2,3,4,5,6,7,8])
print(type(numpy_array3))
print(numpy_array3)
print(numpy_array3.dtype)
print(numpy_array3.shape)

# %%
numpy_array4=np.arange(1,9)
print(type(numpy_array4))
print(numpy_array4)
print(numpy_array4.dtype)
print(numpy_array4.shape)

# %% [markdown]
# ## **2. Change array shape**

# %%
new_array=np.reshape(array,(2,4))
print(new_array)
print(new_array.shape)

# %%
new_array=np.reshape(array,(2,-1))
print(new_array)

# %% [markdown]
# ## **3.Indexing and slicing**

# %%
print(new_array[1,2])
print(new_array[1][2])

# %%
new_array[1,:]

# %%
new_array[0,::2]

# %%
new_array[0,1::2]

# %%
array2=new_array[:,:2]
array2

# %%
new2=np.zeros((8,8))
new2

# %%
new2[2::3,4::2]=array2
new2

# %%
print(new_array)
new_array>2

# %%
new_array[new_array>2]

# %% [markdown]
# ## **4.Calculation**

# %%
print(new_array)
print(new_array.shape)

# %%
new_array+2

# %%
new_array/new_array

# %%
np.sum(new_array,axis=0)

# %%
np.sum(new_array,axis=1)

# %%
np.mean(new_array,axis=0)

# %%
np.mean(new_array,axis=1)

# %%
new_array[0]

# %%
np.dot(new_array[0],new_array[1])

# %% [markdown]
# ## **5. Input & Output**

# %%
np.savetxt("data.txt",new_array)

# %%
array=np.loadtxt("data.txt")
array

# %%
print(array[0])
print(array[:,1])

# %% [markdown]
# ## **6. Math Functions and Symbols**

# %%
np.pi

# %%
theta=np.arange(0,2*np.pi,np.pi/10)
print(type(theta))
print(theta)
print(theta.shape)

# %%
np.sin(theta)

# %% [markdown]
# # Exercise 1. 학생들의 성적 처리하기
#
# > 철수: 수학 70점, 국어 82점, 영어 91점, 과학 87점
# >
# > 영희: 수학 97점, 국어 80점, 영어 92점, 과학 80점
# >
# > 재규: 수학 43점, 국어 99점, 영어 100점, 과학 60점
# >
# > 은지: 수학 100점, 국어 93점, 영어 94점, 과학 97점
#
# 학생들의 성적을 record라는 numpy array에 입력하고 **(1) 개인별 평균과 표준편차**, **(2) 과목별 평균과 표준편차**를 계산하시오
